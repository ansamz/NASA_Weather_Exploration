# %%
import pandas as pd
from datetime import datetime

# %%
path = "C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/DWL/NASA_Weather_Exploration/data/weather_data_Athens.json"

# %%
df = pd.read_json(path)

# %%
df
# Out:
#                  date  latitude  longitude  temperature_2m  \
# 0       -946771200000   37.9838    23.7275        3.870000
# 1       -946767600000   37.9838    23.7275        3.470000
# 2       -946764000000   37.9838    23.7275        3.420000
# 3       -946760400000   37.9838    23.7275        4.170000
# 4       -946756800000   37.9838    23.7275        4.170000
# ...               ...       ...        ...             ...
# 738163  1710615600000   37.9838    23.7275       11.412001
# 738164  1710619200000   37.9838    23.7275       11.112000
# 738165  1710622800000   37.9838    23.7275       11.012000
# 738166  1710626400000   37.9838    23.7275       10.312000
# 738167  1710630000000   37.9838    23.7275        9.862000
#
#         relative_humidity_2m  rain  direct_radiation_instant
# 0                  84.342232   NaN                       NaN
# 1                  86.439995   NaN                       NaN
# 2                  86.434860   NaN                       NaN
# 3                  84.679268   NaN                       NaN
# 4                  84.377243   NaN                       NaN
# ...                      ...   ...                       ...
# 738163             85.189178   0.0                       0.0
# 738164             82.601303   0.0                       0.0
# 738165             80.921928   0.0                       0.0
# 738166             81.103546   0.0                       0.0
# 738167             81.600708   0.0                       0.0
#
# [738168 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['date'], unit='ms')

# %%
df.head(10)
# Out:
#                  date  latitude  longitude  temperature_2m  \
# 0 1940-01-01 00:00:00   37.9838    23.7275            3.87
# 1 1940-01-01 01:00:00   37.9838    23.7275            3.47
# 2 1940-01-01 02:00:00   37.9838    23.7275            3.42
# 3 1940-01-01 03:00:00   37.9838    23.7275            4.17
# 4 1940-01-01 04:00:00   37.9838    23.7275            4.17
# 5 1940-01-01 05:00:00   37.9838    23.7275            4.62
# 6 1940-01-01 06:00:00   37.9838    23.7275            5.17
# 7 1940-01-01 07:00:00   37.9838    23.7275            4.77
# 8 1940-01-01 08:00:00   37.9838    23.7275            4.92
# 9 1940-01-01 09:00:00   37.9838    23.7275            6.92
#
#    relative_humidity_2m  rain  direct_radiation_instant
# 0             84.342232   NaN                       NaN
# 1             86.439995   NaN                       NaN
# 2             86.434860   NaN                       NaN
# 3             84.679268   NaN                       NaN
# 4             84.377243   NaN                       NaN
# 5             83.531952   NaN                       NaN
# 6             83.598854   NaN                       NaN
# 7             80.910507   0.0                 73.564957
# 8             72.928139   0.0                176.121765
# 9             67.038246   0.0                215.579575

# %%
na_per_column = df.isna().sum()
na_per_column
# Out:
# date                        0
# latitude                    0
# longitude                   0
# temperature_2m              0
# relative_humidity_2m        0
# rain                        7
# direct_radiation_instant    7
# dtype: int64

# %%
df = df.dropna()

# %%
na_per_column = df.isna().sum()
na_per_column
# Out:
# date                        0
# latitude                    0
# longitude                   0
# temperature_2m              0
# relative_humidity_2m        0
# rain                        0
# direct_radiation_instant    0
# dtype: int64

# %%
df.head()
# Out:
#                   date  temperature_2m  relative_humidity_2m  rain  \
# 7  1940-01-01 07:00:00            4.77             80.910507   0.0
# 8  1940-01-01 08:00:00            4.92             72.928139   0.0
# 9  1940-01-01 09:00:00            6.92             67.038246   0.0
# 10 1940-01-01 10:00:00            8.02             59.991734   0.0
# 11 1940-01-01 11:00:00            8.37             56.097572   0.0
#
#     direct_radiation_instant
# 7                  73.564957
# 8                 176.121765
# 9                 215.579575
# 10                228.483902
# 11                151.492355

# %%
df = df.drop(columns=["latitude", "longitude"])

# %%
df
# Out:
#                       date  temperature_2m  relative_humidity_2m  rain  \
# 7      1940-01-01 07:00:00        4.770000             80.910507   0.0
# 8      1940-01-01 08:00:00        4.920000             72.928139   0.0
# 9      1940-01-01 09:00:00        6.920000             67.038246   0.0
# 10     1940-01-01 10:00:00        8.020000             59.991734   0.0
# 11     1940-01-01 11:00:00        8.370000             56.097572   0.0
# ...                    ...             ...                   ...   ...
# 738163 2024-03-16 19:00:00       11.412001             85.189178   0.0
# 738164 2024-03-16 20:00:00       11.112000             82.601303   0.0
# 738165 2024-03-16 21:00:00       11.012000             80.921928   0.0
# 738166 2024-03-16 22:00:00       10.312000             81.103546   0.0
# 738167 2024-03-16 23:00:00        9.862000             81.600708   0.0
#
#         direct_radiation_instant
# 7                      73.564957
# 8                     176.121765
# 9                     215.579575
# 10                    228.483902
# 11                    151.492355
# ...                          ...
# 738163                  0.000000
# 738164                  0.000000
# 738165                  0.000000
# 738166                  0.000000
# 738167                  0.000000
#
# [738161 rows x 5 columns]

# %%
df
# Out:
#                       date  temperature_2m  relative_humidity_2m  rain  \
# 7      1940-01-01 07:00:00        4.770000             80.910507   0.0
# 8      1940-01-01 08:00:00        4.920000             72.928139   0.0
# 9      1940-01-01 09:00:00        6.920000             67.038246   0.0
# 10     1940-01-01 10:00:00        8.020000             59.991734   0.0
# 11     1940-01-01 11:00:00        8.370000             56.097572   0.0
# ...                    ...             ...                   ...   ...
# 738163 2024-03-16 19:00:00       11.412001             85.189178   0.0
# 738164 2024-03-16 20:00:00       11.112000             82.601303   0.0
# 738165 2024-03-16 21:00:00       11.012000             80.921928   0.0
# 738166 2024-03-16 22:00:00       10.312000             81.103546   0.0
# 738167 2024-03-16 23:00:00        9.862000             81.600708   0.0
#
#         direct_radiation_instant
# 7                      73.564957
# 8                     176.121765
# 9                     215.579575
# 10                    228.483902
# 11                    151.492355
# ...                          ...
# 738163                  0.000000
# 738164                  0.000000
# 738165                  0.000000
# 738166                  0.000000
# 738167                  0.000000
#
# [738161 rows x 5 columns]
